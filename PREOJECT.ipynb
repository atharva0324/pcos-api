# %% [markdown]
# ### PROJECT

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_columns', None)

# %%
df=pd.read_excel("/Users/atharvashinde/Downloads/archive-8/PCOS_data_without_infertility.xlsx")

# %%
df.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0       1                 1           0          28         44.6        152.0
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#     BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  Hb(g/dl)  \
# 0  19.3           15                78                22     10.48
# 1   NaN           15                74                20     11.70
# 2   NaN           11                72                18     11.80
# 3   NaN           13                72                20     12.00
# 4   NaN           11                72                18     10.00
#
#    Cycle(R/I)  Cycle length(days)  Marraige Status (Yrs)  Pregnant(Y/N)  \
# ...

# %%
df.shape
# Out:
# (541, 45)

# %%
df.describe()
# Out:
#            Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# count  541.000000        541.000000  541.000000  541.000000   541.000000
# mean   271.000000        271.000000    0.327172   31.430684    59.637153
# std    156.317519        156.317519    0.469615    5.411006    11.028287
# min      1.000000          1.000000    0.000000   20.000000    31.000000
# 25%    136.000000        136.000000    0.000000   28.000000    52.000000
# 50%    271.000000        271.000000    0.000000   31.000000    59.000000
# 75%    406.000000        406.000000    1.000000   35.000000    65.000000
# max    541.000000        541.000000    1.000000   48.000000   108.000000
#
#        Height(Cm)          BMI  Blood Group  Pulse rate(bpm)   \
# count   541.000000  242.000000   541.000000        541.000000
# mean    156.484835   23.929752    13.802218         73.247689
# std       6.033545    3.663177     1.840812          4.430285
# ...

# %%
df.isna().sum()
# Out:
# Sl. No                      0
# Patient File No.            0
# PCOS (Y/N)                  0
#  Age (yrs)                  0
# Weight (Kg)                 0
# Height(Cm)                  0
# BMI                       299
# Blood Group                 0
# Pulse rate(bpm)             0
# RR (breaths/min)            0
# Hb(g/dl)                    0
# Cycle(R/I)                  0
# Cycle length(days)          0
# Marraige Status (Yrs)       1
# Pregnant(Y/N)               0
# No. of aborptions           0
#   I   beta-HCG(mIU/mL)      0
# II    beta-HCG(mIU/mL)      0
# FSH(mIU/mL)                 0
# LH(mIU/mL)                  0
# FSH/LH                    532
# Hip(inch)                   0
# Waist(inch)                 0
# Waist:Hip Ratio           532
# TSH (mIU/L)                 0
# AMH(ng/mL)                  0
# PRL(ng/mL)                  0
# Vit D3 (ng/mL)              0
# PRG(ng/mL)                  0
# RBS(mg/dl)                  0
# Weight gain(Y/N)            0
# ...

# %% [markdown]
# ### REMOVE COLUMNS UNNAMED,SI NO,PATIENT NO

# %%
df.drop(columns=['Sl. No','Patient File No.','Unnamed: 44'],inplace=True)
df.head()
# Out:
#    PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)    BMI  Blood Group  \
# 0           0          28         44.6        152.0  19.3           15
# 1           0          36         65.0        161.5   NaN           15
# 2           1          33         68.8        165.0   NaN           11
# 3           0          37         65.0        148.0   NaN           13
# 4           0          25         52.0        161.0   NaN           11
#
#    Pulse rate(bpm)   RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  \
# 0                78                22     10.48           2
# 1                74                20     11.70           2
# 2                72                18     11.80           2
# 3                72                20     12.00           2
# 4                72                18     10.00           2
#
#    Cycle length(days)  Marraige Status (Yrs)  Pregnant(Y/N)  \
# 0                   5                    7.0              0
# ...

# %% [markdown]
# ### UNIVARIATE ANALYSIS
# 1) PCOS

# %%
df['PCOS (Y/N)'].value_counts()
# Out:
# PCOS (Y/N)
# 0    364
# 1    177
# Name: count, dtype: int64

# %% [markdown]
# 2) AGE

# %%
df[' Age (yrs)'].unique()
# Out:
# array([28, 36, 33, 37, 25, 34, 32, 20, 26, 38, 29, 31, 30, 41, 24, 27, 23,
#        35, 39, 40, 22, 44, 21, 42, 43, 45, 47, 48, 46])

# %%
df[' Age (yrs)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df[' Age (yrs)'].describe()
# Out:
# count    541.000000
# mean      31.430684
# std        5.411006
# min       20.000000
# 25%       28.000000
# 50%       31.000000
# 75%       35.000000
# max       48.000000
# Name:  Age (yrs), dtype: float64

# %%
## CHECKING OUTLIERS
q1=df[' Age (yrs)'].quantile(0.25)
q3=df[' Age (yrs)'].quantile(0.75)
IQR=q3-q1
lower_range=q1-1.5*IQR
upper_range=q3+1.5*IQR

# %%
df[' Age (yrs)'].value_counts().sort_values(ascending=True)
# Out:
#  Age (yrs)
# 46     1
# 48     1
# 47     3
# 43     3
# 21     3
# 44     3
# 45     4
# 42     6
# 20     6
# 22     8
# 39     9
# 41     9
# 40    15
# 24    15
# 37    15
# 25    18
# 23    18
# 38    20
# 33    25
# 34    29
# 26    32
# 31    33
# 36    33
# 29    34
# 27    35
# 35    37
# 30    37
# 32    44
# 28    45
# Name: count, dtype: int64

# %%
df[(df[' Age (yrs)']<lower_range) | (df[' Age (yrs)']>upper_range)]
# Out:
#      PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)    BMI  Blood Group  \
# 252           1          47         62.7        154.0   NaN           15
# 318           0          47         60.0        164.5  22.2           13
# 447           1          47         62.7        160.0  24.5           15
# 474           0          48         55.0        151.0  24.1           15
# 509           1          46         54.0        152.0  23.4           13
#
#      Pulse rate(bpm)   RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  \
# 252                72                18      10.0           4
# 318                72                18      13.0           2
# 447                72                18      10.0           4
# 474                70                18       9.4           4
# 509                74                20      14.0           2
#
#      Cycle length(days)  Marraige Status (Yrs)  Pregnant(Y/N)  \
# 252                   4                   30.0              1
# ...

# %%
### WE WONT BE DROPPING THIS as this age ranges are not uncommon in PCOS detection

# %%
df['PCOS (Y/N)'].corr(df[' Age (yrs)'])
# Out:
# np.float64(-0.16851268337734435)

# %%
df[' Age (yrs)']=df[' Age (yrs)'].astype(int)

# %% [markdown]
# 2) WEIGHT

# %%
df['Weight (Kg)'].unique
# Out:
# <bound method Series.unique of 0      44.6
# 1      65.0
# 2      68.8
# 3      65.0
# 4      52.0
#        ...
# 536    50.0
# 537    63.2
# 538    54.0
# 539    50.0
# 540    82.0
# Name: Weight (Kg), Length: 541, dtype: float64>

# %%
df['Weight (Kg)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
### CHECKING FOR OUTLIERS
q1=df['Weight (Kg)'].quantile(0.25)
q3=df['Weight (Kg)'].quantile(0.75)
IQR=q3-q1
lower_range=q1-1.5*IQR
upper_range=q3+1.5*IQR
df[(df['Weight (Kg)']<lower_range) | (df['Weight (Kg)']>upper_range)]
# Out:
#      PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)    BMI  Blood Group  \
# 19            1          30         85.0      165.000   NaN           16
# 79            0          38        108.0      168.000   NaN           14
# 97            1          31         91.4      154.000   NaN           15
# 130           1          24         89.0      173.000   NaN           17
# 146           0          36         85.0      164.000   NaN           13
# 177           1          24         89.0      173.000   NaN           17
# 178           1          37         88.0      168.000   NaN           12
# 221           1          31         31.0      158.000   NaN           15
# 244           1          39        104.0      164.400   NaN           15
# 250           1          45         85.0      153.000   NaN           15
# 255           0          36         32.0      154.000   NaN           15
# 265           0          40         32.0      152.000   NaN           15
# ...

# %%
### THIS OUTLIERS TOTALLY MAKE SENSE AND THEY ARE AGES THAT AREN'T BIOLOGICAALY IMPOSSIBLE

# %%
df['PCOS (Y/N)'].corr(df['Weight (Kg)'])
# Out:
# np.float64(0.2119379658075521)

# %% [markdown]
# 3) ### HEIGHT

# %%
df['Height(Cm) '].value_counts()
# Out:
# Height(Cm)
# 158.000    67
# 152.000    66
# 150.000    46
# 154.000    38
# 155.000    27
# 161.000    24
# 160.000    24
# 156.000    21
# 162.000    21
# 153.000    19
# 165.000    17
# 148.000    17
# 159.000    16
# 163.000    14
# 157.000    13
# 164.000    13
# 158.496    11
# 151.000     9
# 170.000     6
# 145.000     6
# 149.000     5
# 164.592     5
# 168.000     4
# 146.000     4
# 161.544     4
# 147.000     3
# 173.000     3
# 164.500     3
# 155.448     3
# 171.000     2
# 172.000     2
# 169.000     2
# 166.000     2
# 144.000     2
# 152.400     2
# 143.000     2
# 167.000     2
# 167.640     2
# 142.000     2
# 170.688     2
# 161.500     1
# 137.000     1
# 180.000     1
# 167.700     1
# 158.400     1
# 173.700     1
# 153.400     1
# 164.400     1
# 140.000     1
# 146.304     1
# Name: count, dtype: int64

# %%
df['Height(Cm) '].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
## NORMALLY DISTRIBUTED
## LETS CHECK ITS CORR WITH PCOS COLUMN
df['PCOS (Y/N)'].corr(df['Height(Cm) '])
# Out:
# np.float64(0.06825366741167602)

# %% [markdown]
# ## 4) BMI

# %%
df['BMI'].isna().sum()
# Out:
# np.int64(299)

# %%
### as there are 299 missing values, what we can do is drop this column and create completely new one using already existing height and weight columns
### now the weight column is in correct units to calculate weight but we need to deal with height as it is in cm and we have to convert it into m

# %%
df.drop('BMI',axis=1,inplace=True)

# %%
df['Height(m)']=df['Height(Cm) ']/100
df['BMI']=df['Weight (Kg)']/(df['Height(m)']**2)

# %%
df.drop('Height(Cm) ',axis=1,inplace=True)

# %%
df.head()
# Out:
#    PCOS (Y/N)   Age (yrs)  Weight (Kg)  Blood Group  Pulse rate(bpm)   \
# 0           0          28         44.6           15                78
# 1           0          36         65.0           15                74
# 2           1          33         68.8           11                72
# 3           0          37         65.0           13                72
# 4           0          25         52.0           11                72
#
#    RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  Cycle length(days)  \
# 0                22     10.48           2                   5
# 1                20     11.70           2                   5
# 2                18     11.80           2                   5
# 3                20     12.00           2                   5
# 4                18     10.00           2                   5
#
#    Marraige Status (Yrs)  Pregnant(Y/N)  No. of aborptions  \
# 0                    7.0              0                  0
# ...

# %%
### NEW BMI COLUMN CREATED

# %%
df['BMI'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['PCOS (Y/N)'].corr(df['BMI'])
# Out:
# np.float64(0.20017568138475847)

# %% [markdown]
# ### 5) BLOOD GROUP

# %%
## lets convert blood group from numerical back to categorical
df['Blood Group']=df['Blood Group'].map({11:'A+',12:'A-',13:'B+',14:'B-',15:'O+',16:'O-',17:'AB+',18:'AB-'})

# %%
df['Blood Group'].value_counts()
# Out:
# Blood Group
# O+     206
# B+     135
# A+     108
# AB+     42
# O-      19
# B-      16
# A-      13
# AB-      2
# Name: count, dtype: int64

# %%
pd.crosstab(df['Blood Group'], df['PCOS (Y/N)'],normalize='index')*100
# Out:
# PCOS (Y/N)           0          1
# Blood Group
# A+           68.518519  31.481481
# A-           69.230769  30.769231
# AB+          61.904762  38.095238
# AB-          50.000000  50.000000
# B+           68.888889  31.111111
# B-           62.500000  37.500000
# O+           67.961165  32.038835
# O-           57.894737  42.105263

# %%
df.columns
# Out:
# Index(['PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)', 'Blood Group',
#        'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)',
#        'Cycle length(days)', 'Marraige Status (Yrs)', 'Pregnant(Y/N)',
#        'No. of aborptions', '  I   beta-HCG(mIU/mL)', 'II    beta-HCG(mIU/mL)',
#        'FSH(mIU/mL)', 'LH(mIU/mL)', 'FSH/LH', 'Hip(inch)', 'Waist(inch)',
#        'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)',
#        'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)',
#        'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)',
#        'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)',
#        'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)',
#        'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)',
#        'Endometrium (mm)', 'Height(m)', 'BMI'],
#       dtype='str')

# %% [markdown]
# ### 6) Pulse Rate

# %%
df['Pulse rate(bpm) '].describe()
# Out:
# count    541.000000
# mean      73.247689
# std        4.430285
# min       13.000000
# 25%       72.000000
# 50%       72.000000
# 75%       74.000000
# max       82.000000
# Name: Pulse rate(bpm) , dtype: float64

# %%
df['Pulse rate(bpm) '].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Pulse rate(bpm) '].corr(df['PCOS (Y/N)'])
# Out:
# np.float64(0.09182051784854225)

# %% [markdown]
# ### 7) RR (breaths/min)

# %%
df['RR (breaths/min)'].describe()
# Out:
# count    541.000000
# mean      19.243993
# std        1.688629
# min       16.000000
# 25%       18.000000
# 50%       18.000000
# 75%       20.000000
# max       28.000000
# Name: RR (breaths/min), dtype: float64

# %%
### usually RR (breaths/min) lies in range (12-20) per minutes

# %%
df['RR (breaths/min)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
### IT looks normal, small  peaks in between but its okay
df['RR (breaths/min)'].isna().sum()
# Out:
# np.int64(0)

# %%
df['RR (breaths/min)'].corr(df['PCOS (Y/N)'])
# Out:
# np.float64(0.03692775359145962)

# %% [markdown]
# ### 8) Hb(g/dl) [Hemoglobin (grams/decilitre)]

# %%
df['Hb(g/dl)'].describe()
# Out:
# count    541.000000
# mean      11.160037
# std        0.866904
# min        8.500000
# 25%       10.500000
# 50%       11.000000
# 75%       11.700000
# max       14.800000
# Name: Hb(g/dl), dtype: float64

# %%
df['Hb(g/dl)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Hb(g/dl)'].corr(df['PCOS (Y/N)'])
# Out:
# np.float64(0.08716999881621908)

# %%
df['Hb(g/dl)'].isna().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 0           0          28         44.6          O+                78
# 1           0          36         65.0          O+                74
# 2           1          33         68.8          A+                72
# 3           0          37         65.0          B+                72
# 4           0          25         52.0          A+                72
#
#    RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  Cycle length(days)  \
# 0                22     10.48           2                   5
# 1                20     11.70           2                   5
# 2                18     11.80           2                   5
# 3                20     12.00           2                   5
# 4                18     10.00           2                   5
#
#    Marraige Status (Yrs)  Pregnant(Y/N)  No. of aborptions  \
# 0                    7.0              0                  0
# ...

# %% [markdown]
# ### 9) CYCLE (REGURAL/IRREGULAR)

# %%
df['Cycle(R/I)'].value_counts()
# Out:
# Cycle(R/I)
# 2    390
# 4    150
# 5      1
# Name: count, dtype: int64

# %%
df['Cycle(R/I)']=df['Cycle(R/I)'].map({2:'Regular',4:'Irregular',5:'Irregular'})

# %%
df.head()
# Out:
#    PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 0           0          28         44.6          O+                78
# 1           0          36         65.0          O+                74
# 2           1          33         68.8          A+                72
# 3           0          37         65.0          B+                72
# 4           0          25         52.0          A+                72
#
#    RR (breaths/min)  Hb(g/dl) Cycle(R/I)  Cycle length(days)  \
# 0                22     10.48    Regular                   5
# 1                20     11.70    Regular                   5
# 2                18     11.80    Regular                   5
# 3                20     12.00    Regular                   5
# 4                18     10.00    Regular                   5
#
#    Marraige Status (Yrs)  Pregnant(Y/N)  No. of aborptions  \
# 0                    7.0              0                  0
# 1                   11.0              1                  0
# ...

# %%
df['Cycle(R/I)'].value_counts()
# Out:
# Cycle(R/I)
# Regular      390
# Irregular    151
# Name: count, dtype: int64

# %%
df['Cycle(R/I)'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cycle(R/I)'>

# %% [markdown]
# ### 10) Cycle Length

# %%
df['Cycle length(days)'].value_counts()
# Out:
# Cycle length(days)
# 5     276
# 6      91
# 4      61
# 2      38
# 3      36
# 7      19
# 9       9
# 11      5
# 8       2
# 12      2
# 0       1
# 10      1
# Name: count, dtype: int64

# %%
df['Cycle length(days)'].corr(df['PCOS (Y/N)'])
# Out:
# np.float64(-0.178480044721789)

# %%
### AS CYCLE LENGTH CAN"T BE JUST BEWT 0-12, this column might be encoded
### also as we already have CYCLE (R/I) that checks irregullarity in cycle we should drop Cycyle length column
df.drop('Cycle length(days)',axis=1,inplace=True)

# %%
df.head(2)
# Out:
#    PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 0           0          28         44.6          O+                78
# 1           0          36         65.0          O+                74
#
#    RR (breaths/min)  Hb(g/dl) Cycle(R/I)  Marraige Status (Yrs)  \
# 0                22     10.48    Regular                    7.0
# 1                20     11.70    Regular                   11.0
#
#    Pregnant(Y/N)  No. of aborptions    I   beta-HCG(mIU/mL)  \
# 0              0                  0                    1.99
# 1              1                  0                   60.80
#
#   II    beta-HCG(mIU/mL)  FSH(mIU/mL)  LH(mIU/mL)  FSH/LH  Hip(inch)  \
# 0                   1.99         7.95        3.68     NaN         36
# 1                   1.99         6.73        1.09     NaN         38
#
#    Waist(inch)  Waist:Hip Ratio  TSH (mIU/L) AMH(ng/mL)  PRL(ng/mL)  \
# 0           30              NaN         0.68       2.07       45.16
# ...

# %% [markdown]
# ### 11)MARRIAGE STATUS

# %%
df['Marraige Status (Yrs)'].value_counts()
# Out:
# Marraige Status (Yrs)
# 4.0     52
# 3.0     51
# 8.0     48
# 5.0     47
# 10.0    44
# 7.0     43
# 6.0     38
# 2.0     29
# 12.0    29
# 13.0    24
# 9.0     17
# 11.0    16
# 15.0    14
# 1.0     13
# 14.0    12
# 16.0     8
# 3.5      7
# 2.5      7
# 18.0     7
# 17.0     6
# 1.5      5
# 6.5      4
# 20.0     2
# 22.0     2
# 19.0     2
# 4.5      2
# 30.0     2
# 25.0     2
# 23.0     2
# 0.0      1
# 8.5      1
# 7.5      1
# 24.0     1
# 2.2      1
# Name: count, dtype: int64

# %%
df['Marraige Status (Yrs)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
### LETS CHECK FOR THE OUTLIERS

# %%
df['Marraige Status (Yrs)'].skew()
# Out:
# np.float64(1.1421801114733567)

# %%
q1=df['Marraige Status (Yrs)'].quantile(0.25)
q3=df['Marraige Status (Yrs)'].quantile(0.75)
IQR=q3-q1
lower_range=q1-1.5*IQR
upper_range=q3+1.5*IQR
df[(df['Marraige Status (Yrs)']<lower_range) | (df['Marraige Status (Yrs)']>upper_range)]
# Out:
#      PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 15            0          38         80.5          B+                78
# 90            0          44         74.4         AB+                78
# 220           0          39         61.0          A+                72
# 252           1          47         62.7          O+                72
# 272           0          43         40.0          O+                72
# 318           0          47         60.0          B+                72
# 326           0          45         54.0          B+                72
# 408           0          45         57.0          O+                72
# 442           0          40         56.0          O+                72
# 447           1          47         62.7          O+                72
# 474           0          48         55.0          O+                70
#
#      RR (breaths/min)  Hb(g/dl) Cycle(R/I)  Marraige Status (Yrs)  \
# ...

# %%
### so we do have outliers , but these are impossible values, these are values that make sense so we would prolly keep it

# %%
df['Marraige Status (Yrs)'].corr(df['PCOS (Y/N)'])
# Out:
# np.float64(-0.11289660614014004)

# %% [markdown]
# ### 12) Pregnant(Y/N)

# %%
df['Pregnant(Y/N)'].value_counts()
# Out:
# Pregnant(Y/N)
# 0    335
# 1    206
# Name: count, dtype: int64

# %%
df['Pregnant(Y/N)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.countplot(x=df['Pregnant(Y/N)'])
# Out:
# <Axes: xlabel='Pregnant(Y/N)', ylabel='count'>

# %%
    pd.crosstab(df['Pregnant(Y/N)'],df['PCOS (Y/N)'],normalize='index')*100
# Out:
# PCOS (Y/N)             0          1
# Pregnant(Y/N)
# 0              66.268657  33.731343
# 1              68.932039  31.067961

# %%
df['Pregnant(Y/N)'].corr(df['PCOS (Y/N)'])
# Out:
# np.float64(-0.02756463006484282)

# %% [markdown]
# 13)No. of aborptions

# %%
df['No. of aborptions'].value_counts()
# Out:
# No. of aborptions
# 0    437
# 1     69
# 2     22
# 3     10
# 4      2
# 5      1
# Name: count, dtype: int64

# %%
df['No. of aborptions'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='No. of aborptions'>

# %%
df['No. of aborptions'].corr(df['PCOS (Y/N)'])
# Out:
# np.float64(-0.057158393772236)

# %%
pd.crosstab(df['No. of aborptions'], df['PCOS (Y/N)'], normalize='index')
# Out:
# PCOS (Y/N)                0         1
# No. of aborptions
# 0                  0.665904  0.334096
# 1                  0.681159  0.318841
# 2                  0.636364  0.363636
# 3                  0.900000  0.100000
# 4                  1.000000  0.000000
# 5                  1.000000  0.000000

# %%
## we will bin the values as abortions=0 and abortions>0 .

# %%
df['had_abortion']=(df['No. of aborptions']>0).astype(int)

# %%
## now drop No. of aborptions columns
df.drop('No. of aborptions',axis=1,inplace=True)

# %% [markdown]
# ### LETS DO EDA ON EVERY BINARY COLUMNS ,(Y/N) COLUMNS TOGETHER

# %%
column=['Weight gain(Y/N)', 'hair growth(Y/N)',
       'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)',
       'Fast food (Y/N)', 'Reg.Exercise(Y/N)']
for i in column:
    print("Column :", i)
    print("no.of missing values:" ,df[i].isna().sum())
    print(df[i].value_counts())
# Out:
# Column : Weight gain(Y/N)
# no.of missing values: 0
# Weight gain(Y/N)
# 0    337
# 1    204
# Name: count, dtype: int64
# Column : hair growth(Y/N)
# no.of missing values: 0
# hair growth(Y/N)
# 0    393
# 1    148
# Name: count, dtype: int64
# Column : Skin darkening (Y/N)
# no.of missing values: 0
# Skin darkening (Y/N)
# 0    375
# 1    166
# Name: count, dtype: int64
# Column : Hair loss(Y/N)
# no.of missing values: 0
# Hair loss(Y/N)
# 0    296
# 1    245
# Name: count, dtype: int64
# Column : Pimples(Y/N)
# no.of missing values: 0
# Pimples(Y/N)
# 0    276
# 1    265
# Name: count, dtype: int64
# Column : Fast food (Y/N)
# no.of missing values: 1
# Fast food (Y/N)
# 1.0    278
# 0.0    262
# Name: count, dtype: int64
# Column : Reg.Exercise(Y/N)
# no.of missing values: 0
# Reg.Exercise(Y/N)
# 0    407
# 1    134
# Name: count, dtype: int64

# %% [markdown]
# ###  13)I   beta-HCG(mIU/mL)	& II    beta-HCG(mIU/mL)

# %%
## I   beta-HCG(mIU/mL)	II    beta-HCG(mIU/mL) these two column are use for identifying wether women is pregnnt or not
### these both column refers to same tests taken 1- first time taken and 2-follow up
##  ih values of any of the column > 5 then  the female is pregnant.

# %%
### as we alredy have pregnant column lets drop it.

# %%
### but first lets check wether its true that hcg >5 means pregnant

# %%
df['II    beta-HCG(mIU/mL)'] = pd.to_numeric(df['II    beta-HCG(mIU/mL)'], errors='coerce')
df.loc[ df['II    beta-HCG(mIU/mL)'] > 5].groupby('Pregnant(Y/N)').size()
# Out:
# Pregnant(Y/N)
# 0     41
# 1    162
# dtype: int64

# %%
## its true , so we will drop it
df.drop(columns=['  I   beta-HCG(mIU/mL)','II    beta-HCG(mIU/mL)'],inplace=True)

# %%
df.head()
# Out:
#    PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 0           0          28         44.6          O+                78
# 1           0          36         65.0          O+                74
# 2           1          33         68.8          A+                72
# 3           0          37         65.0          B+                72
# 4           0          25         52.0          A+                72
#
#    RR (breaths/min)  Hb(g/dl) Cycle(R/I)  Marraige Status (Yrs)  \
# 0                22     10.48    Regular                    7.0
# 1                20     11.70    Regular                   11.0
# 2                18     11.80    Regular                   10.0
# 3                20     12.00    Regular                    4.0
# 4                18     10.00    Regular                    1.0
#
#    Pregnant(Y/N)  FSH(mIU/mL)  LH(mIU/mL)  FSH/LH  Hip(inch)  Waist(inch)  \
# 0              0         7.95        3.68     NaN         36           30
# ...

# %% [markdown]
# ### 14) FSH,LH

# %%
df['FSH(mIU/mL)'].value_counts()
# Out:
# FSH(mIU/mL)
# 5.71     6
# 5.01     5
# 3.99     5
# 4.96     5
# 1.00     5
#         ..
# 7.06     1
# 10.06    1
# 5.07     1
# 11.96    1
# 4.40     1
# Name: count, Length: 371, dtype: int64

# %%
df['FSH(mIU/mL)'].describe()
# Out:
# count     541.000000
# mean       14.601832
# std       217.022081
# min         0.210000
# 25%         3.300000
# 50%         4.850000
# 75%         6.410000
# max      5052.000000
# Name: FSH(mIU/mL), dtype: float64

# %%
### theres one outlier lets deal with it
q1=df['FSH(mIU/mL)'].quantile(0.25)
q3=df['FSH(mIU/mL)'].quantile(0.75)
IQR=q3-q1
lower_range=q1-1.5*IQR
upper_range=q3+1.5*IQR
df['FSH(mIU/mL)']=np.where(df['FSH(mIU/mL)']>upper_range,upper_range,df['FSH(mIU/mL)'])

# %%
df['FSH(mIU/mL)'].describe()
# Out:
# count    541.000000
# mean       4.993200
# std        2.211918
# min        0.210000
# 25%        3.300000
# 50%        4.850000
# 75%        6.410000
# max       11.075000
# Name: FSH(mIU/mL), dtype: float64

# %%
sns.histplot(df['FSH(mIU/mL)'], bins=30, kde=True)
plt.xlabel('FSH (mIU/mL)')
plt.title('Distribution of FSH')
plt.show()

# %%
df['FSH(mIU/mL)'].corr(df['PCOS (Y/N)'])
# Out:
# np.float64(-0.11176781644682994)

# %% [markdown]
# ### LH

# %%
df['LH(mIU/mL)'].value_counts()
# Out:
# LH(mIU/mL)
# 2.02    5
# 2.30    5
# 1.97    5
# 1.00    5
# 0.10    5
#        ..
# 2.07    1
# 4.66    1
# 9.38    1
# 3.50    1
# 4.33    1
# Name: count, Length: 342, dtype: int64

# %%
df['LH(mIU/mL)'].describe()
# Out:
# count     541.000000
# mean        6.469919
# std        86.673255
# min         0.020000
# 25%         1.020000
# 50%         2.300000
# 75%         3.680000
# max      2018.000000
# Name: LH(mIU/mL), dtype: float64

# %%
sns.histplot(df['LH(mIU/mL)'], bins=30, kde=True)
plt.xlabel('LH(mIU/mL)')
plt.title('Distribution of LH')
plt.show()

# %%
q1=df['LH(mIU/mL)'].quantile(0.25)
q3=df['LH(mIU/mL)'].quantile(0.75)
IQR=q3-q1
lower_range=q1-1.5*IQR
upper_range=q3+1.5*IQR
df[(df['LH(mIU/mL)']>20)]
# Out:
#      PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 455           1          32         52.0          B+                70
#
#      RR (breaths/min)  Hb(g/dl) Cycle(R/I)  Marraige Status (Yrs)  \
# 455                18       9.4    Regular                   12.0
#
#      Pregnant(Y/N)  FSH(mIU/mL)  LH(mIU/mL)  FSH/LH  Hip(inch)  Waist(inch)  \
# 455              0         4.33      2018.0     NaN         36           32
#
#      Waist:Hip Ratio  TSH (mIU/L) AMH(ng/mL)  PRL(ng/mL)  Vit D3 (ng/mL)  \
# 455              NaN          2.1        7.7       40.47           41.04
#
#      PRG(ng/mL)  RBS(mg/dl)  Weight gain(Y/N)  hair growth(Y/N)  \
# 455        0.25        93.0                 0                 0
#
#      Skin darkening (Y/N)  Hair loss(Y/N)  Pimples(Y/N)  Fast food (Y/N)  \
# 455                     0               0             1              0.0
#
#      Reg.Exercise(Y/N)  BP _Systolic (mmHg)  BP _Diastolic (mmHg)  \
# ...

# %%
df['LH(mIU/mL)']=np.where(df['LH(mIU/mL)']>upper_range,upper_range,df['LH(mIU/mL)'])

# %%
sns.histplot(df['LH(mIU/mL)'], bins=30, kde=True)
plt.xlabel('LH(mIU/mL)')
plt.title('Distribution of LH')
plt.show()

# %% [markdown]
# ### 15) Cretaing new column Lh/fsh

# %%
df['LH-FSH ratio']=df['LH(mIU/mL)']/df['FSH(mIU/mL)']

# %%
df.head()
# Out:
#    PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 0           0          28         44.6          O+                78
# 1           0          36         65.0          O+                74
# 2           1          33         68.8          A+                72
# 3           0          37         65.0          B+                72
# 4           0          25         52.0          A+                72
#
#    RR (breaths/min)  Hb(g/dl) Cycle(R/I)  Marraige Status (Yrs)  \
# 0                22     10.48    Regular                    7.0
# 1                20     11.70    Regular                   11.0
# 2                18     11.80    Regular                   10.0
# 3                20     12.00    Regular                    4.0
# 4                18     10.00    Regular                    1.0
#
#    Pregnant(Y/N)  FSH(mIU/mL)  LH(mIU/mL)  FSH/LH  Hip(inch)  Waist(inch)  \
# 0              0         7.95        3.68     NaN         36           30
# ...

# %%
df['LH-FSH ratio'].corr(df['PCOS (Y/N)'])
# Out:
# np.float64(0.13592510444772674)

# %%
df.drop('FSH/LH',axis=1,inplace=True)

# %%
sns.histplot(df['LH-FSH ratio'], bins=30, kde=True)
plt.xlabel('LH-FSH ratio')
plt.title('LH-FSH ratio')
plt.show()

# %%
df.columns
# Out:
# Index(['PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)', 'Blood Group',
#        'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)',
#        'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'FSH(mIU/mL)', 'LH(mIU/mL)',
#        'Hip(inch)', 'Waist(inch)', 'Waist:Hip Ratio', 'TSH (mIU/L)',
#        'AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)',
#        'RBS(mg/dl)', 'Weight gain(Y/N)', 'hair growth(Y/N)',
#        'Skin darkening (Y/N)', 'Hair loss(Y/N)', 'Pimples(Y/N)',
#        'Fast food (Y/N)', 'Reg.Exercise(Y/N)', 'BP _Systolic (mmHg)',
#        'BP _Diastolic (mmHg)', 'Follicle No. (L)', 'Follicle No. (R)',
#        'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)',
#        'Height(m)', 'BMI', 'had_abortion', 'LH-FSH ratio'],
#       dtype='str')

# %% [markdown]
# ### 16) WAIST,HIP and WAIST:Hip ratio

# %%
### checking min,max, mean null values and distribution

# %%
columns=['Hip(inch)', 'Waist(inch)']
for i in columns:
    print(df[i].describe())
    print(f"Null values in {i} = {df[i].isna().sum()}")
    print(df[i].value_counts())
# Out:
# count    541.000000
# mean      37.992606
# std        3.967920
# min       26.000000
# 25%       36.000000
# 50%       38.000000
# 75%       40.000000
# max       48.000000
# Name: Hip(inch), dtype: float64
# Null values in Hip(inch) = 0
# Hip(inch)
# 38    106
# 36     65
# 39     57
# 40     52
# 42     49
# 37     33
# 34     31
# 32     23
# 35     21
# 44     20
# 45     17
# 30     15
# 41     14
# 28     11
# 46      9
# 48      7
# 33      7
# 26      3
# 43      1
# Name: count, dtype: int64
# count    541.000000
# mean      33.841035
# std        3.596894
# min       24.000000
# 25%       32.000000
# 50%       34.000000
# 75%       36.000000
# max       47.000000
# Name: Waist(inch), dtype: float64
# Null values in Waist(inch) = 0
# Waist(inch)
# 32    86
# 34    85
# 35    66
# 36    54
# 30    51
# 33    41
# 38    34
# 37    23
# 28    21
# 40    13
# 31    13
# 39    11
# 26     8
# 42     6
# 44     5
# 41     4
# 29     4
# 27     4
# 25     4
# 24     4
# 46     2
# ...

# %%
df['Hip(inch)'].plot(kind='kde')
print(df['Hip(inch)'].skew())
# Out:
# -0.20087268517536633

# %%
### checking for womens with hip< 30
df.loc[df['Hip(inch)']<30]
# Out:
#      PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 404           0          26         38.0          O+                72
# 451           1          30         44.0          A-                72
# 457           1          31         38.0          O+                80
# 494           0          30         48.0          O+                80
# 496           0          34         45.0         AB+                70
# 504           0          33         48.0         AB+                72
# 506           0          35         42.0          A+                78
# 519           0          28         53.0          O-                72
# 520           1          27         50.0          B+                72
# 522           0          29         52.0          B+                72
# 525           0          27         48.0          B+                72
# 533           1          26         53.5          B-                70
# ...

# %%
## checking distribution in waist
sns.kdeplot(data=df,x='Waist(inch)')
# Out:
# <Axes: xlabel='Waist(inch)', ylabel='Density'>

# %%
df.loc[df['Waist(inch)']<28]
# Out:
#      PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 34            0          28         50.0          O+                76
# 42            0          28         33.0          B+                78
# 278           1          45         50.0         AB+                72
# 404           0          26         38.0          O+                72
# 420           1          25         45.6          A+                74
# 428           1          28         48.0          A+                74
# 436           0          29         48.0          O+                70
# 451           1          30         44.0          A-                72
# 457           1          31         38.0          O+                80
# 494           0          30         48.0          O+                80
# 496           0          34         45.0         AB+                70
# 504           0          33         48.0         AB+                72
# ...

# %%
### lets fill in all the missing values from the column wait:hip ratio by feature engineering it
df['Waist:Hip Ratio']=df['Waist(inch)']/df['Hip(inch)']

# %%
df.head(2)
# Out:
#    PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 0           0          28         44.6          O+                78
# 1           0          36         65.0          O+                74
#
#    RR (breaths/min)  Hb(g/dl) Cycle(R/I)  Marraige Status (Yrs)  \
# 0                22     10.48    Regular                    7.0
# 1                20     11.70    Regular                   11.0
#
#    Pregnant(Y/N)  FSH(mIU/mL)  LH(mIU/mL)  Hip(inch)  Waist(inch)  \
# 0              0         7.95        3.68         36           30
# 1              1         6.73        1.09         38           32
#
#    Waist:Hip Ratio  TSH (mIU/L) AMH(ng/mL)  PRL(ng/mL)  Vit D3 (ng/mL)  \
# 0         0.833333         0.68       2.07       45.16            17.1
# 1         0.842105         3.16       1.53       20.09            61.3
#
#    PRG(ng/mL)  RBS(mg/dl)  Weight gain(Y/N)  hair growth(Y/N)  \
# 0        0.57        92.0                 0                 0
# ...

# %%
df[['Waist(inch)', 'Hip(inch)', 'Waist:Hip Ratio']].corr()
# Out:
#                  Waist(inch)  Hip(inch)  Waist:Hip Ratio
# Waist(inch)         1.000000   0.873411         0.257641
# Hip(inch)           0.873411   1.000000        -0.243061
# Waist:Hip Ratio     0.257641  -0.243061         1.000000

# %%
df.drop(columns=['Waist(inch)', 'Hip(inch)'],inplace=True)

# %% [markdown]
# ### 17) Dealing with
# 'TSH (mIU/L)', 'AMH(ng/mL)',  'PRL(ng/mL)',  'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)' columns

# %%
columns=['TSH (mIU/L)','AMH(ng/mL)', 'PRL(ng/mL)', 'Vit D3 (ng/mL)', 'PRG(ng/mL)',
       'RBS(mg/dl)']
for i in columns:
    print(f"Column name : {i}")
    print(df[i].describe())
    print(f"Null values in {i} = {df[i].isna().sum()}")
# Out:
# Column name : TSH (mIU/L)
# count    541.000000
# mean       2.981281
# std        3.755532
# min        0.040000
# 25%        1.480000
# 50%        2.260000
# 75%        3.570000
# max       65.000000
# Name: TSH (mIU/L), dtype: float64
# Null values in TSH (mIU/L) = 0
# Column name : AMH(ng/mL)
# count     541
# unique    301
# top         1
# freq        9
# Name: AMH(ng/mL), dtype: int64
# Null values in AMH(ng/mL) = 0
# Column name : PRL(ng/mL)
# count    541.000000
# mean      24.321497
# std       14.970391
# min        0.400000
# 25%       14.520000
# 50%       21.920000
# 75%       29.890000
# max      128.240000
# Name: PRL(ng/mL), dtype: float64
# Null values in PRL(ng/mL) = 0
# Column name : Vit D3 (ng/mL)
# count     541.000000
# mean       49.915874
# std       346.206599
# min         0.000000
# 25%        20.800000
# 50%        25.900000
# 75%        34.500000
# max      6014.660000
# Name: Vit D3 (ng/mL), dtype: float64
# Null values in Vit D3 (ng/mL) = 0
# ...

# %%
df['TSH (mIU/L)'].sort_values(ascending=False).head(10)
### as there only one valye with tsh=65 and as it is biologically possible we keep it
# Out:
# 37     65.00
# 233    25.91
# 278    22.59
# 346    20.85
# 535    17.20
# 168    16.99
# 3      16.41
# 305    16.00
# 128    15.68
# 7      12.18
# Name: TSH (mIU/L), dtype: float64

# %%
### dealing with AMH
df['AMH(ng/mL)'].value_counts()
# Out:
# AMH(ng/mL)
# 1       9
# 2.5     9
# 4.5     7
# 1.2     6
# 4.2     6
#        ..
# 0.19    1
# 6.3     1
# 19.6    1
# 18.2    1
# 7.6     1
# Name: count, Length: 301, dtype: int64

# %%
df['AMH(ng/mL)']=pd.to_numeric(df['AMH(ng/mL)'],errors='coerce')

# %%
df['AMH(ng/mL)'].describe()
# Out:
# count    540.000000
# mean       5.624191
# std        5.881608
# min        0.100000
# 25%        2.010000
# 50%        3.700000
# 75%        6.925000
# max       66.000000
# Name: AMH(ng/mL), dtype: float64

# %%
df['AMH(ng/mL)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.loc[df['AMH(ng/mL)']>20]
# Out:
#      PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 110           0          21         59.0          O+                72
# 113           1          32         63.0         AB+                72
# 180           1          30         70.0          O-                74
# 213           1          26         70.0          O+                72
# 217           1          34         72.0          B+                72
# 267           1          28         58.9          A+                72
# 268           0          25         53.5          A+                72
# 279           0          26         54.0          A+                72
# 293           1          27         36.0          B+                70
# 346           1          28         83.0          A+                74
# 402           1          28         65.0          A+                74
# 445           1          26         72.0          O+                72
#
# ...

# %%
### THERES ONE HIGH VALUE FOR AMH WHICH IS IMPOSSIBLE i.e AMH=66, so we would cap it
df['AMH(ng/mL)']=np.where(df['AMH(ng/mL)']>30,29,df['AMH(ng/mL)'])

# %%
df['AMH(ng/mL)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['AMH(ng/mL)'].corr(df['PCOS (Y/N)'])
# Out:
# np.float64(0.2705234237452544)

# %%
### DEALING WITH PRL
df['PRL(ng/mL)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
### lets check outliers
df.loc[df['PRL(ng/mL)']==6014]
# Out:
# Empty DataFrame
# Columns: [PCOS (Y/N),  Age (yrs), Weight (Kg), Blood Group, Pulse rate(bpm) , RR (breaths/min), Hb(g/dl), Cycle(R/I), Marraige Status (Yrs), Pregnant(Y/N), FSH(mIU/mL), LH(mIU/mL), Waist:Hip Ratio, TSH (mIU/L), AMH(ng/mL), PRL(ng/mL), Vit D3 (ng/mL), PRG(ng/mL), RBS(mg/dl), Weight gain(Y/N), hair growth(Y/N), Skin darkening (Y/N), Hair loss(Y/N), Pimples(Y/N), Fast food (Y/N), Reg.Exercise(Y/N), BP _Systolic (mmHg), BP _Diastolic (mmHg), Follicle No. (L), Follicle No. (R), Avg. F size (L) (mm), Avg. F size (R) (mm), Endometrium (mm), Height(m), BMI, had_abortion, LH-FSH ratio]
# Index: []

# %%
## DEALING WITH VITAMIN COLUMN
df['Vit D3 (ng/mL)'].head(10).sort_values(ascending=False)
# Out:
# 1    61.3
# 5    52.4
# 2    49.7
# 4    43.8
# 6    42.7
# 7    38.0
# 3    33.4
# 9    27.7
# 8    21.8
# 0    17.1
# Name: Vit D3 (ng/mL), dtype: float64

# %%
df.loc[df['Vit D3 (ng/mL)']>100]
# Out:
#      PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 191           1          29         63.0         AB+                74
# 195           1          35         60.0          B+                72
#
#      RR (breaths/min)  Hb(g/dl) Cycle(R/I)  Marraige Status (Yrs)  \
# 191                18      11.0  Irregular                    8.0
# 195                20      13.2  Irregular                   14.0
#
#      Pregnant(Y/N)  FSH(mIU/mL)  LH(mIU/mL)  Waist:Hip Ratio  TSH (mIU/L)  \
# 191              0        3.630        1.02         0.897436         2.66
# 195              0       11.075        3.39         0.921053         2.42
#
#      AMH(ng/mL)  PRL(ng/mL)  Vit D3 (ng/mL)  PRG(ng/mL)  RBS(mg/dl)  \
# 191        6.41       29.08         6014.66        0.25       123.0
# 195        6.65       16.34         5418.60        0.31       100.0
#
#      Weight gain(Y/N)  hair growth(Y/N)  Skin darkening (Y/N)  Hair loss(Y/N)  \
# ...

# %%
df.loc[df['Vit D3 (ng/mL)']<100].sort_values(by='Vit D3 (ng/mL)',ascending=False)
# Out:
#      PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 208           0          27         51.0          B+                72
# 207           0          32         60.0          O+                73
# 180           1          30         70.0          O-                74
# 436           0          29         48.0          O+                70
# 102           1          38         64.3          A+                78
# ..          ...         ...          ...         ...               ...
# 201           0          28         56.0          B+                72
# 189           1          23         58.0          O+                74
# 175           1          27         58.0          O+                74
# 196           1          35         56.0          B-                73
# 216           1          36         66.0          O+                72
#
#      RR (breaths/min)  Hb(g/dl) Cycle(R/I)  Marraige Status (Yrs)  \
# ...

# %%
df['Vit D3 (ng/mL)']=np.where(df['Vit D3 (ng/mL)']>100,90,df['Vit D3 (ng/mL)'])

# %%
df['Vit D3 (ng/mL)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
### DEALING WITH PRG(ng/mL)	
df['PRG(ng/mL)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.loc[df['PRG(ng/mL)']>10]
# Out:
#      PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 41            0          29         78.0          B+                72
# 484           0          31         63.0          A+                72
#
#      RR (breaths/min)  Hb(g/dl) Cycle(R/I)  Marraige Status (Yrs)  \
# 41                 16      12.8    Regular                    2.0
# 484                20      10.8    Regular                    5.0
#
#      Pregnant(Y/N)  FSH(mIU/mL)  LH(mIU/mL)  Waist:Hip Ratio  TSH (mIU/L)  \
# 41               1         5.60        2.13         0.857143         0.93
# 484              0         5.28        3.46         0.923077         2.48
#
#      AMH(ng/mL)  PRL(ng/mL)  Vit D3 (ng/mL)  PRG(ng/mL)  RBS(mg/dl)  \
# 41         3.88       20.46           14.36        85.0        92.0
# 484        6.26       28.08           16.25        25.3       116.0
#
#      Weight gain(Y/N)  hair growth(Y/N)  Skin darkening (Y/N)  Hair loss(Y/N)  \
# ...

# %%
### DEALING WITH RBS(mg/dl)
df['RBS(mg/dl)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['RBS(mg/dl)'].sort_values(ascending=False)
# Out:
# 178    350.0
# 432    225.0
# 146    160.0
# 230    160.0
# 409    146.0
#        ...
# 51      70.0
# 50      70.0
# 267     70.0
# 268     70.0
# 99      60.0
# Name: RBS(mg/dl), Length: 541, dtype: float64

# %%
df.columns
# Out:
# Index(['PCOS (Y/N)', ' Age (yrs)', 'Weight (Kg)', 'Blood Group',
#        'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)',
#        'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'FSH(mIU/mL)', 'LH(mIU/mL)',
#        'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)',
#        'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)',
#        'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)',
#        'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)',
#        'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)',
#        'Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)',
#        'Endometrium (mm)', 'Height(m)', 'BMI', 'had_abortion', 'LH-FSH ratio'],
#       dtype='str')

# %% [markdown]
# ### DEALING WITH
# 'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Follicle No. (L)','Follicle No. (R)', 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)', 'Endometrium (mm)' columns

# %%
## 'BP _Systolic (mmHg)'
df['BP _Systolic (mmHg)'].describe()
# Out:
# count    541.000000
# mean     114.661738
# std        7.384556
# min       12.000000
# 25%      110.000000
# 50%      110.000000
# 75%      120.000000
# max      140.000000
# Name: BP _Systolic (mmHg), dtype: float64

# %%
df['BP _Systolic (mmHg)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['BP _Systolic (mmHg)']=np.where(df['BP _Systolic (mmHg)']<90,90,df['BP _Systolic (mmHg)'])

# %%
df['BP _Systolic (mmHg)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
## dealing with  'BP _Diastolic (mmHg)'
df[ 'BP _Diastolic (mmHg)'].describe()
# Out:
# count    541.000000
# mean      76.927911
# std        5.574112
# min        8.000000
# 25%       70.000000
# 50%       80.000000
# 75%       80.000000
# max      100.000000
# Name: BP _Diastolic (mmHg), dtype: float64

# %%
df['BP _Diastolic (mmHg)']=np.where(df[ 'BP _Diastolic (mmHg)']<60,60,df[ 'BP _Diastolic (mmHg)'])

# %%
df[ 'BP _Diastolic (mmHg)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
### dealing with 'Follicle No. (L)','Follicle No. (R)'
df['Follicle No. (L)'].describe()
# Out:
# count    541.000000
# mean       6.129390
# std        4.229294
# min        0.000000
# 25%        3.000000
# 50%        5.000000
# 75%        9.000000
# max       22.000000
# Name: Follicle No. (L), dtype: float64

# %%
df['Follicle No. (R)'].describe()
# Out:
# count    541.000000
# mean       6.641405
# std        4.436889
# min        0.000000
# 25%        3.000000
# 50%        6.000000
# 75%       10.000000
# max       20.000000
# Name: Follicle No. (R), dtype: float64

# %%
plt.figure(figsize=(14,6))
plt.subplot(121)
sns.kdeplot(data=df,x='Follicle No. (L)')
plt.title('Follicle No. (L)')
plt.subplot(122)
sns.kdeplot(data=df,x='Follicle No. (R)')
plt.title('Follicle No. (R)')
# Out:
# Text(0.5, 1.0, 'Follicle No. (R)')

# %% [markdown]
# ### DEALING with 'Avg. F size (L) (mm)', 'Avg. F size (R) (mm)'

# %%
df['Avg. F size (L) (mm)'].describe()
# Out:
# count    541.000000
# mean      15.018115
# std        3.566839
# min        0.000000
# 25%       13.000000
# 50%       15.000000
# 75%       18.000000
# max       24.000000
# Name: Avg. F size (L) (mm), dtype: float64

# %%
df['Avg. F size (R) (mm)'].describe()
# Out:
# count    541.000000
# mean      15.451701
# std        3.318848
# min        0.000000
# 25%       13.000000
# 50%       16.000000
# 75%       18.000000
# max       24.000000
# Name: Avg. F size (R) (mm), dtype: float64

# %%
plt.figure(figsize=(14,6))
plt.subplot(121)
sns.kdeplot(data=df,x='Avg. F size (L) (mm)')
plt.title('Avg. F size (L) (mm)')
plt.subplot(122)
sns.kdeplot(data=df,x='Avg. F size (R) (mm)')
plt.title('Avg. F size (R) (mm)')
# Out:
# Text(0.5, 1.0, 'Avg. F size (R) (mm)')

# %%
# dealing with Endometrium (mm)
df['Endometrium (mm)'].describe()
# Out:
# count    541.000000
# mean       8.475915
# std        2.165381
# min        0.000000
# 25%        7.000000
# 50%        8.500000
# 75%        9.800000
# max       18.000000
# Name: Endometrium (mm), dtype: float64

# %%
df['Endometrium (mm)'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
### CREATING NEW COLUMN AVG FOLLICLE SIZE based on sizes of follicle in left and right ovary
### also creating ne wcolumn Total Follicles which would be sum of follicles from left and right ovary
df['Avg_Follicle_size']=(df['Avg. F size (R) (mm)']+df['Avg. F size (L) (mm)'])/2

# %%
df['Total_follicle']=df['Follicle No. (R)']+df['Follicle No. (L)']

# %%
df.drop(columns=['Avg. F size (R) (mm)','Avg. F size (L) (mm)','Follicle No. (L)','Follicle No. (R)'],inplace=True)

# %%
df.head()
# Out:
#    PCOS (Y/N)   Age (yrs)  Weight (Kg) Blood Group  Pulse rate(bpm)   \
# 0           0          28         44.6          O+                78
# 1           0          36         65.0          O+                74
# 2           1          33         68.8          A+                72
# 3           0          37         65.0          B+                72
# 4           0          25         52.0          A+                72
#
#    RR (breaths/min)  Hb(g/dl) Cycle(R/I)  Marraige Status (Yrs)  \
# 0                22     10.48    Regular                    7.0
# 1                20     11.70    Regular                   11.0
# 2                18     11.80    Regular                   10.0
# 3                20     12.00    Regular                    4.0
# 4                18     10.00    Regular                    1.0
#
#    Pregnant(Y/N)  FSH(mIU/mL)  LH(mIU/mL)  Waist:Hip Ratio  TSH (mIU/L)  \
# 0              0         7.95        3.68         0.833333         0.68
# ...

# %%
df.rename(columns={
    ' Age (yrs)': 'Age (yrs)'}, inplace=True)

# %%
df.columns
# Out:
# Index(['PCOS (Y/N)', 'Age (yrs)', 'Weight (Kg)', 'Blood Group',
#        'Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)', 'Cycle(R/I)',
#        'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'FSH(mIU/mL)', 'LH(mIU/mL)',
#        'Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)',
#        'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)', 'Weight gain(Y/N)',
#        'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)',
#        'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)',
#        'BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Endometrium (mm)',
#        'Height(m)', 'BMI', 'had_abortion', 'LH-FSH ratio', 'Avg_Follicle_size',
#        'Total_follicle'],
#       dtype='str')

# %%
df_eda=df[['PCOS (Y/N)', 'Age (yrs)', 'Weight (Kg)','Height(m)', 'BMI', 'had_abortion', 'Blood Group','Cycle(R/I)',
       'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'Weight gain(Y/N)',
       'hair growth(Y/N)', 'Skin darkening (Y/N)', 'Hair loss(Y/N)',
       'Pimples(Y/N)', 'Fast food (Y/N)', 'Reg.Exercise(Y/N)','Pulse rate(bpm) ', 'RR (breaths/min)', 'Hb(g/dl)','FSH(mIU/mL)', 'LH(mIU/mL)',
       'LH-FSH ratio','Waist:Hip Ratio', 'TSH (mIU/L)', 'AMH(ng/mL)', 'PRL(ng/mL)',
       'Vit D3 (ng/mL)', 'PRG(ng/mL)', 'RBS(mg/dl)','BP _Systolic (mmHg)', 'BP _Diastolic (mmHg)', 'Avg_Follicle_size',
       'Total_follicle', 'Endometrium (mm)']]

# %%
### checking correation of all of our columns with target columns

corr_df = (
    df.drop(columns=['Blood Group','Cycle(R/I)']).corr()[['PCOS (Y/N)']]
    .rename(columns={'PCOS (Y/N)': 'corr_with_pcos'})
    .sort_values(by='corr_with_pcos', ascending=False)
)
corr_df
# Out:
#                        corr_with_pcos
# PCOS (Y/N)                   1.000000
# Total_follicle               0.660315
# Skin darkening (Y/N)         0.475733
# hair growth(Y/N)             0.464667
# Weight gain(Y/N)             0.441047
# Fast food (Y/N)              0.377933
# Pimples(Y/N)                 0.286077
# AMH(ng/mL)                   0.270523
# Weight (Kg)                  0.211938
# BMI                          0.200176
# Hair loss(Y/N)               0.172879
# LH-FSH ratio                 0.135925
# Avg_Follicle_size            0.132885
# Endometrium (mm)             0.106648
# Pulse rate(bpm)              0.091821
# Hb(g/dl)                     0.087170
# LH(mIU/mL)                   0.081165
# Height(m)                    0.068254
# Reg.Exercise(Y/N)            0.065337
# RBS(mg/dl)                   0.048922
# RR (breaths/min)             0.036928
# BP _Diastolic (mmHg)         0.030351
# Waist:Hip Ratio              0.012414
# PRL(ng/mL)                   0.005143
# ...

# %%
df_eda.columns
df_eda= df_eda.rename(columns={
    "PCOS (Y/N)": "pcos",
    "Age (yrs)": "age",
    "Weight (Kg)": "weight",
    "Height(m)": "height",
    "BMI": "bmi",
    "had_abortion": "had_abortion",
    "Blood Group": "blood_group",
    "Cycle(R/I)": "cycle_type",
    "Marraige Status (Yrs)": "marriage_years",
    "Pregnant(Y/N)": "pregnant",
    "Weight gain(Y/N)": "weight_gain",
    "hair growth(Y/N)": "hair_growth",
    "Skin darkening (Y/N)": "skin_darkening",
    "Hair loss(Y/N)": "hair_loss",
    "Pimples(Y/N)": "pimples",
    "Fast food (Y/N)": "fast_food",
    "Reg.Exercise(Y/N)": "regular_exercise",
    "Pulse rate(bpm) ": "pulse_rate",
    "RR (breaths/min)": "respiratory_rate",
    "Hb(g/dl)": "hemoglobin",
    "FSH(mIU/mL)": "fsh",
    "LH(mIU/mL)": "lh",
    "LH-FSH ratio": "lh_fsh_ratio",
    "Waist:Hip Ratio": "waist_hip_ratio",
    "TSH (mIU/L)": "tsh",
    "AMH(ng/mL)": "amh",
    "PRL(ng/mL)": "prolactin",
    "Vit D3 (ng/mL)": "vitamin_d3",
    "PRG(ng/mL)": "progesterone",
    "RBS(mg/dl)": "random_blood_sugar",
    "BP _Systolic (mmHg)": "bp_systolic",
    "BP _Diastolic (mmHg)": "bp_diastolic",
    "Avg_Follicle_size": "avg_follicle_size",
    "Total_follicle": "total_follicles",
    "Endometrium (mm)": "endometrium_thickness"
})

# %%
# Out:
#    pcos  age  weight  height        bmi  had_abortion blood_group cycle_type  \
# 0     0   28    44.6   1.520  19.304017             0          O+    Regular
# 1     0   36    65.0   1.615  24.921163             0          O+    Regular
# 2     1   33    68.8   1.650  25.270891             0          A+    Regular
# 3     0   37    65.0   1.480  29.674945             0          B+    Regular
# 4     0   25    52.0   1.610  20.060954             0          A+    Regular
#
#    marriage_years  pregnant  weight_gain  hair_growth  skin_darkening  \
# 0             7.0         0            0            0               0
# 1            11.0         1            0            0               0
# 2            10.0         1            0            0               0
# 3             4.0         0            0            0               0
# 4             1.0         1            0            0               0
#
#    hair_loss  pimples  fast_food  regular_exercise  pulse_rate  \
# ...

# %%
### loading this dataset
df_eda.to_csv("Feature Engnineered dataset.csv",index=False)
